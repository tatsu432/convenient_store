# %%
# import the modules and libraries
from selenium import webdriver
from time import sleep
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import re

import scrape_module5

# %%
search_word = "デイリーヤマザキ"
lists_Daily_YAMAZAKI = []
English_word = "Daily_YAMAZAKI"

scrape_module5.scrape_convenience(search_word, lists_Daily_YAMAZAKI, English_word)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15532/876085782.py in <module>
#       3 English_word = "Daily_YAMAZAKI"
#       4
# ----> 5 scrape_module5.scrape_convenience(search_word, lists_Daily_YAMAZAKI, English_word)
#
# c:\Users\81808\document1\self_study\Scraping\convenience_store\scrape_module5.py in scrape_convenience(search_word, lists_convenient_store, english_word)
#      63
#      64             # click one of the componenets in the list
# ---> 65             elem.click()
#      66             sleep(1)
#      67
#
# c:\Users\81808\anaconda3\envs\py38\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ...

# %%
scrape_module5.show_lists(lists_Daily_YAMAZAKI)
# Out:
# ['Daily_YAMAZAKI新青森駅前店', '40.83004729914401', '140.69587108624']
# ['Daily_YAMAZAKI大鰐店', '40.52378976994402', '140.56840045006993']
# ['Daily_YAMAZAKI平川店', '40.586012205782', '140.56840257133']
# ['Daily_YAMAZAKI平賀松崎店', '40.59416337341199', '140.53457168891998']
# ['Daily_YAMAZAKI青森古川店', '40.82390461814302', '140.73670273292998']
# ['Daily_YAMAZAKI新青森駅前店', '40.83004729914401', '140.69587108624']
# ['Daily_YAMAZAKI弘前小栗山店', '40.558926472455994', '140.49040000676996']
# ['Daily_YAMAZAKI 青森地区本部', '40.81304420689901', '140.73545204854997']
# ['Daily_YAMAZAKI青森旭町通り店', '40.813837370117994', '140.73570298375']
# ['Daily_YAMAZAKI蟹田店', '41.03877089156296', '140.64430821504993']
# ['Daily_YAMAZAKI大鰐店', '40.52379724286499', '140.56839553606005']
# ['Daily_YAMAZAKI平川店', '40.58602455520199', '140.56838043204993']
# ['Daily_YAMAZAKI平賀松崎店', '40.594130452737005', '140.53456799566993']
# ['Daily_YAMAZAKI青森古川店', '40.823894988578985', '140.73668633649004']
# ...

# %%
scrape_module5.write_elem(lists_Daily_YAMAZAKI, "Daily_YAMAZAKI")
